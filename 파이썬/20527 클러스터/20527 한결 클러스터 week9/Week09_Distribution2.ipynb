# %%
import gdown
url='https://drive.google.com/uc?id=1VpY5gjx_hcpWbk1KIvye5K5yjU0vUEpk'
filename='pt_book_fix.csv'
gdown.download(url, filename, quiet = False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VpY5gjx_hcpWbk1KIvye5K5yjU0vUEpk
# To: /content/pt_book_fix.csv
# 100%|██████████| 28.3M/28.3M [00:00<00:00, 94.8MB/s]
# 'pt_book_fix.csv'

# %%
import pandas as pd

pt_book=pd.read_csv(filename, low_memory=False)
pt_book.head()
# Out:
#    번호                                도서명              저자   출판사  발행년도  \
# 0   1                           세이노의 가르침          세이노 지음   데이원  2023
# 1   2                         서울대생의 비밀과외  소린TV,안소린 [공]지음  다산에듀  2023
# 2   3  (현직 고등학교 선생님들이 직접 고른) 생기부 필독서 100        주경아 외 지음   센시오  2023
# 3   4                        당연하게도 나는 너를          이꽃님 지음  우리학교  2023
# 4   5                             고요한 우연          김수빈 지음  문학동네  2023
#
#           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9.79117E+12      NaN    0  NaN  199.1     1     0  2023-03-30
# 1  9.79113E+12      NaN    1  NaN  373.7     1     0  2023-03-30
# 2  9.79117E+12      NaN    1  NaN  376.6     1     0  2023-03-30
# 3  9.79117E+12      NaN    4  NaN  813.7     1     0  2023-03-30
# 4  9.78895E+12      NaN    0  NaN  813.7     1     0  2023-03-30

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([1,2,3,4],[1,2,3,4])
plt.show()

# %%
plt.scatter(pt_book["번호"],pt_book["대출건수"])
plt.show()

# %%
plt.scatter(pt_book["도서권수"],pt_book["대출건수"])
plt.show()

# %%
average_borrows=pt_book['대출건수']/pt_book['도서권수']
plt.scatter(average_borrows,pt_book["대출건수"], alpha=0.1)
plt.show()

# %%
import gdown

url='https://drive.google.com/uc?id=1wHEX8SLbYdbaq2FjCoH4f882wadYUpL6'
filename='pt_book_fix.csv'
gdown.download(url, filename, quiet = False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wHEX8SLbYdbaq2FjCoH4f882wadYUpL6
# To: /content/pt_book_fix.csv
# 100%|██████████| 28.3M/28.3M [00:00<00:00, 72.3MB/s]
# 'pt_book_fix.csv'

# %%
import matplotlib.pyplot as plt

plt.hist([1,3,6,8,10,11,13],bins=5)
plt.show()

# %%
plt.hist(pt_book['대출건수'])
plt.show()

# %%
plt.hist(pt_book['대출건수'])
plt.yscale('log')
plt.show()

# %%
plt.hist(pt_book['대출건수'], bins=100)
plt.yscale('log')
plt.show()

# %%
title_len=pt_book['도서명'].apply(len)
plt.hist(title_len,bins=100)
plt.xscale('log')
plt.show()

# %%
plt.boxplot(pt_book[['대출건수','도서권수']],whis=10)
plt.yscale('log')
plt.show()
